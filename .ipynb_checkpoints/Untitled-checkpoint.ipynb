# %% [markdown]
# # Liverpool Assignment
# - Installing Packages
# - Preparing and Exploring the Dataset
# - Unsupervised Learning
# - Supervised Learning

# %% [markdown]
# ## Installing packages

# %%
#tells matplotlib to use the inline backend which renders the graphs in the notebook

# %matplotlib inline 

#imports the packages needed and renames some for convenience 

from IPython.display import Image
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the datasets

# %% [markdown]
# For this assignment I used the "Student Performance Data Set" from the UCI Machine Learning archive (https://archive.ics.uci.edu/ml/datasets/student+performance#).
#
# This is two datasets on educational performance at two schools in Portugal.
#
# The first dataset is on performance in maths (n = 395), the second is on performance in Portugese (n = 649).
#
# Whilst students in the first dataset *seem* to be present in the second dataset, the data appears to be have been gathered at different times in the year and for a small number of students certain attributes have changed which makes a join of the datasets of questionable validity.
#
# I choose to explore two possibilites:
#
# 1. Removing the students who's attributes have changed, whist being wary of the bias that may occur due to the likelyhood that students whose attributes have changed are not a typical group.
# 2. Treating both datasets seperately, whilst being wary that there may be a loss of information as performance in Maths and Portugese are likely to be related to some extent.

# %%
Image("../Liverpool Assignment/Attribute_table.png")

# %% [markdown]
# - Importing the maths data

# %%
db_maths = pd.read_csv("../Liverpool Assignment/Data/student-mat.csv", sep = ";", header = 0)
db_maths.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
db_maths.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
db_maths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# freetime      395 non-null int64
# goout         395 non-null int64
# Dalc          395 non-null int64
# Walc          395 non-null int64
# health        395 non-null int64
# absences      395 non-null int64
# G1            395 non-null int64
# G2            395 non-null int64
# G3            395 non-null int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %% [markdown]
# - Importing the Portugese data

# %%
db_port = pd.read_csv("../Liverpool Assignment/Data/student-por.csv", sep = ";", header = 0)
db_port.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
db_port.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
db_port.info()

# %% [markdown]
# - Joining the datasets

# %%
db_maths.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
db_join = db_maths.merge(db_port,
                        on =["school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"],\
                        how = 'outer'
                        )

# %%
db_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382 entries, 0 to 381
# Data columns (total 53 columns):
# school          382 non-null object
# sex             382 non-null object
# age             382 non-null int64
# address         382 non-null object
# famsize         382 non-null object
# Pstatus         382 non-null object
# Medu            382 non-null int64
# Fedu            382 non-null int64
# Mjob            382 non-null object
# Fjob            382 non-null object
# reason          382 non-null object
# guardian_x      382 non-null object
# traveltime_x    382 non-null int64
# studytime_x     382 non-null int64
# failures_x      382 non-null int64
# schoolsup_x     382 non-null object
# famsup_x        382 non-null object
# paid_x          382 non-null object
# activities_x    382 non-null object
# nursery         382 non-null object
# higher_x        382 non-null object
# internet        382 non-null object
# romantic_x      382 non-null object
# famrel_x        382 non-null int64
# freetime_x      382 non-null int64
# goout_x         382 non-null int64
# Dalc_x          382 non-null int64
# Walc_x          382 non-null int64
# health_x        382 non-null int64
# absences_x      382 non-null int64
# G1_x            382 non-null int64
# G2_x            382 non-null int64
# G3_x            382 non-null int64
# guardian_y      382 non-null object
# traveltime_y    382 non-null int64
# studytime_y     382 non-null int64
# failures_y      382 non-null int64
# schoolsup_y     382 non-null object
# famsup_y        382 non-null object
# paid_y          382 non-null object
# activities_y    382 non-null object
# higher_y        382 non-null object
# romantic_y      382 non-null object
# famrel_y        382 non-null int64
# freetime_y      382 non-null int64
# goout_y         382 non-null int64
# Dalc_y          382 non-null int64
# Walc_y          382 non-null int64
# health_y        382 non-null int64
# absences_y      382 non-null int64
# G1_y            382 non-null int64
# G2_y            382 non-null int64
# G3_y            382 non-null int64
# dtypes: int64(29), object(24)
# memory usage: 161.2+ KB

# %%
db_join.head()
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# - Unsupervised Learning
